# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n.yaml")

# %%
model = YOLO("yolo11n.pt")

# %%
results = model.train(
data="ppe-mask-glove-mergev2.v16i.yolov11/data.yaml",
epochs=300,
imgsz=500,
project="ppe",
plots=True,
save=True,
batch=32
)

results = model.val()
# Out:
# Ultralytics 8.4.90 🚀 Python-3.12.3 torch-2.12.1+cu130 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 3769MiB)
# ...
